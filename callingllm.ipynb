# %%
import sys
# !{sys.executable} -m pip install python-dotenv
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
# !{sys.executable} -m pip install python-dotenv langchain-google-genai
# Out:
# ...
#      ---------------------------------------- 0.0/56.3 kB ? eta -:--:--
#      --------------------- ------------------ 30.7/56.3 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 56.3/56.3 kB 980.3 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/43.1 kB ? eta -:--:--
#      ---------------------------------------- 43.1/43.1 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/81.6 kB ? eta -:--:--
#    ---------------------------------------- 81.6/81.6 kB 2.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ----------- ---------------------------- 0.3/1.1 MB 6.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.1 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.0/1.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 6.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/572.0 kB ? eta -:--:--
# ...

# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
# Out:
# True

# %%
llm = ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response=llm.invoke("How many moons jupiter has")
print(response.text)
# Out:
# Direct use of automatic function calling (AFC) in Models.generate_content is not recommended. Instead, we recommend to use AFC in Chat.send_message. Similarly, direct use of AFC in Models.generate_content_stream is not recommended. Instead, we recommend to use AFC in Chat.send_message_stream.
# Jupiter has **95 officially recognized moons**.
#
# Here are a few interesting facts about them:
#
# *   **The Galilean Moons:** The four largest and most famous are Io, Europa, Ganymede, and Callisto. They were discovered by Galileo Galilei in 1610.
# *   **The Largest Moon:** Ganymede is not only Jupiter's largest moon but is also the largest moon in the entire solar system (it is even larger than the planet Mercury).
# *   **Constant Changes:** The number of moons often changes as astronomers use more powerful telescopes to discover smaller "irregular" moons that orbit far away from the planet.

# %%
##what if u want to give instruction
llm=ChatGoogleGenerativeAI(model="gemma-4-31b-it")
response=llm.invoke([["system","You are an helpful assistant that answers in one line"],["human","most famous colour in the world and why ?"]])
print(response.text)
# Out:
# Blue is widely considered the most popular color globally because it is universally associated with the sky and the ocean, evoking feelings of calm and stability.

# %%
prompt= "write a single tagline for a quirky coffee shop. Only output the tagline, nothing else"
llm=ChatGoogleGenerativeAI(model='gemini-3.5-flash', temperature=0) #temperature parameters in gemini models is in the range 0 to 2
response=llm.invoke(prompt)
print(response.text)
# Out:
# Caffeine for the wonderfully odd.

# %%
prompt= "write a single tagline for a quirky coffee shop. Only output the tagline, nothing else"
llm=ChatGoogleGenerativeAI(model='gemini-3.5-flash', temperature=2) #temperature parameters in gemini models is in the range 0 to 2
response=llm.invoke(prompt)
print(response.text)
# Out:
# Brewed for the delightfully different.

# %% [markdown]
# ### CALLING LLM USING GROQ MODELS

# %%
import sys
# !{sys.executable} -m pip install langchain_groq
# Out:
# ...
#    ---------------------------------------- 0.0/137.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/137.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/137.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/137.5 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/137.5 kB ? eta -:--:--
#    ----------------- --------------------- 61.4/137.5 kB 251.0 kB/s eta 0:00:01
#    ------------------------------------ - 133.1/137.5 kB 491.5 kB/s eta 0:00:01
#    -------------------------------------- 137.5/137.5 kB 451.3 kB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_groq import ChatGroq
llm= ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")
messages=llm.invoke([("system","You are an helpful assistant that answers in one line",), ("human","most famous colour in the world and why ?")])
print(messages.content)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[26], line 2
#       1 llm= ChatGroq(model="qwen/qwen3-32b", reasoning_format="parsed")
# ----> 2 messages=llm.invoke([("system","You are an helpful assistant that answers in one line",), ("human","most famous colour in the world and why ?")])
#       3 print(messages.content)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:488, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     474 @override
#     475 def invoke(
#     476     self,
#    (...)    481     **kwargs: Any,
#     482 ) -> AIMessage:
#     483     config = ensure_config(config)
#     484     return cast(
#     485         "AIMessage",
#     486         cast(
#     487             "ChatGeneration",
# --> 488             self.generate_prompt(
# ...

# %%
from groq import Groq

client = Groq()

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# canopylabs/orpheus-v1-english
# canopylabs/orpheus-arabic-saudi
# openai/gpt-oss-20b
# qwen/qwen3.8-27b
# meta-llama/llama-prompt-guard-2-86m
# whisper-large-v3
# openai/gpt-oss-safeguard-20b
# meta-llama/llama-prompt-guard-2-22m
# allam-2-7b
# openai/gpt-oss-120b
# whisper-large-v3-turbo

# %%
from langchain_groq import ChatGroq
llm= ChatGroq(model="qwen/qwen3.8-27b", reasoning_format="parsed")
messages=llm.invoke([("system","You are an helpful assistant that answers in one line",), ("human","most famous colour in the world and why ?")])
print(messages.content)
# Out:
# Blue is widely considered the most famous or popular color in the world, largely due to its universal appeal, association with calmness and stability, and its dominance in branding and design.
